# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('t20i_info.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
#batting team
#bowling team
#city
#current_score
#balls left
#wickets_left
#current_run_rate
#last five

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'][0].split(' ')[0]
# Out:
# 'Melbourne'

# %%
cities = np.where(df['city'].isnull(), df['venue'].str.split().apply(lambda x : x[0]), df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue
# 0                    0  Melbourne  Melbourne Cricket Ground
# 1                    0  Melbourne  Melbourne Cricket Ground
# 2                    0  Melbourne  Melbourne Cricket Ground
# 3                    0  Melbourne  Melbourne Cricket Ground
# 4                    0  Melbourne  Melbourne Cricket Ground
# ...                ...        ...                       ...
# 63883                0    Colombo       R Premadasa Stadium
# 63884                0    Colombo       R Premadasa Stadium
# 63885      DM de Silva    Colombo       R Premadasa Stadium
# 63886                0    Colombo       R Premadasa Stadium
# 63887                0    Colombo       R Premadasa Stadium
#
# [50501 rows x 9 columns]

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# 1                    0  Melbourne  Melbourne Cricket Ground              0
# 2                    0  Melbourne  Melbourne Cricket Ground              1
# 3                    0  Melbourne  Melbourne Cricket Ground              3
# 4                    0  Melbourne  Melbourne Cricket Ground              3
# ...                ...        ...                       ...            ...
# 63883                0    Colombo       R Premadasa Stadium            125
# 63884                0    Colombo       R Premadasa Stadium            125
# 63885      DM de Silva    Colombo       R Premadasa Stadium            125
# 63886                0    Colombo       R Premadasa Stadium            127
# 63887                0    Colombo       R Premadasa Stadium            128
#
# [50501 rows x 10 columns]

# %%
df['over'] = df['ball'].apply(lambda x : str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x : str(x).split(".")[1])

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# 1                    0  Melbourne  Melbourne Cricket Ground              0
# 2                    0  Melbourne  Melbourne Cricket Ground              1
# 3                    0  Melbourne  Melbourne Cricket Ground              3
# 4                    0  Melbourne  Melbourne Cricket Ground              3
# ...                ...        ...                       ...            ...
# 63883                0    Colombo       R Premadasa Stadium            125
# 63884                0    Colombo       R Premadasa Stadium            125
# 63885      DM de Silva    Colombo       R Premadasa Stadium            125
# 63886                0    Colombo       R Premadasa Stadium            127
# 63887                0    Colombo       R Premadasa Stadium            128
#
#       over ball_no
# 0        0       1
# 1        0       2
# 2        0       3
# 3        0       4
# 4        0       5
# ...    ...     ...
# 63883   19       3
# 63884   19       4
# 63885   19       5
# 63886   19       6
# 63887   19       7
#
# [50501 rows x 12 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6 + df['ball_no'].astype('int'))

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# 1                    0  Melbourne  Melbourne Cricket Ground              0
# 2                    0  Melbourne  Melbourne Cricket Ground              1
# 3                    0  Melbourne  Melbourne Cricket Ground              3
# 4                    0  Melbourne  Melbourne Cricket Ground              3
# ...                ...        ...                       ...            ...
# 63883                0    Colombo       R Premadasa Stadium            125
# 63884                0    Colombo       R Premadasa Stadium            125
# 63885      DM de Silva    Colombo       R Premadasa Stadium            125
# 63886                0    Colombo       R Premadasa Stadium            127
# 63887                0    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled
# 0        0       1             1
# 1        0       2             2
# 2        0       3             3
# 3        0       4             4
# 4        0       5             5
# ...    ...     ...           ...
# 63883   19       3           117
# 63884   19       4           118
# 63885   19       5           119
# 63886   19       6           120
# 63887   19       7           121
#
# [50501 rows x 13 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x: 0 if x < 0 else x)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city                     venue  current_score  \
# 0                    0  Melbourne  Melbourne Cricket Ground              0
# 1                    0  Melbourne  Melbourne Cricket Ground              0
# 2                    0  Melbourne  Melbourne Cricket Ground              1
# 3                    0  Melbourne  Melbourne Cricket Ground              3
# 4                    0  Melbourne  Melbourne Cricket Ground              3
# ...                ...        ...                       ...            ...
# 63883                0    Colombo       R Premadasa Stadium            125
# 63884                0    Colombo       R Premadasa Stadium            125
# 63885      DM de Silva    Colombo       R Premadasa Stadium            125
# 63886                0    Colombo       R Premadasa Stadium            127
# 63887                0    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left
# 0        0       1             1         119
# 1        0       2             2         118
# 2        0       3             3         117
# 3        0       4             4         116
# 4        0       5             5         115
# ...    ...     ...           ...         ...
# 63883   19       3           117           3
# 63884   19       4           118           2
# 63885   19       5           119           1
# 63886   19       6           120           0
# 63887   19       7           121           0
#
# [50501 rows x 14 columns]

# %%
df['player_dismissed'].apply(lambda x: 1 if x != '0' else '0')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 63883    0
# 63884    0
# 63885    1
# 63886    0
# 63887    0
# Name: player_dismissed, Length: 50501, dtype: object

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 1 if x != '0' else 0)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 63883                 0    Colombo       R Premadasa Stadium            125
# 63884                 0    Colombo       R Premadasa Stadium            125
# 63885                 1    Colombo       R Premadasa Stadium            125
# 63886                 0    Colombo       R Premadasa Stadium            127
# 63887                 0    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left
# 0        0       1             1         119
# 1        0       2             2         118
# 2        0       3             3         117
# 3        0       4             4         116
# 4        0       5             5         115
# ...    ...     ...           ...         ...
# 63883   19       3           117           3
# 63884   19       4           118           2
# 63885   19       5           119           1
# 63886   19       6           120           0
# 63887   19       7           121           0
#
# [50501 rows x 14 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].astype('int')

# %%
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']

# %%
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 63883                 8    Colombo       R Premadasa Stadium            125
# 63884                 8    Colombo       R Premadasa Stadium            125
# 63885                 9    Colombo       R Premadasa Stadium            125
# 63886                 9    Colombo       R Premadasa Stadium            127
# 63887                 9    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left  wickets_left
# 0        0       1             1         119            10
# 1        0       2             2         118            10
# 2        0       3             3         117            10
# 3        0       4             4         116            10
# 4        0       5             5         115            10
# ...    ...     ...           ...         ...           ...
# 63883   19       3           117           3             2
# 63884   19       4           118           2             2
# 63885   19       5           119           1             1
# 63886   19       6           120           0             1
# 63887   19       7           121           0             1
#
# [50501 rows x 15 columns]

# %%
df['crr'] = (df['current_score']*6) / df['balls_bowled']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 63883                 8    Colombo       R Premadasa Stadium            125
# 63884                 8    Colombo       R Premadasa Stadium            125
# 63885                 9    Colombo       R Premadasa Stadium            125
# 63886                 9    Colombo       R Premadasa Stadium            127
# 63887                 9    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left  wickets_left       crr
# 0        0       1             1         119            10  0.000000
# 1        0       2             2         118            10  0.000000
# 2        0       3             3         117            10  2.000000
# 3        0       4             4         116            10  4.500000
# 4        0       5             5         115            10  3.600000
# ...    ...     ...           ...         ...           ...       ...
# 63883   19       3           117           3             2  6.410256
# 63884   19       4           118           2             2  6.355932
# 63885   19       5           119           1             1  6.302521
# 63886   19       6           120           0             1  6.350000
# 63887   19       7           121           0             1  6.347107
#
# [50501 rows x 16 columns]

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 63883                 8    Colombo       R Premadasa Stadium            125
# 63884                 8    Colombo       R Premadasa Stadium            125
# 63885                 9    Colombo       R Premadasa Stadium            125
# 63886                 9    Colombo       R Premadasa Stadium            127
# 63887                 9    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left  wickets_left       crr  \
# 0        0       1             1         119            10  0.000000
# 1        0       2             2         118            10  0.000000
# 2        0       3             3         117            10  2.000000
# 3        0       4             4         116            10  4.500000
# 4        0       5             5         115            10  3.600000
# ...    ...     ...           ...         ...           ...       ...
# 63883   19       3           117           3             2  6.410256
# 63884   19       4           118           2             2  6.355932
# 63885   19       5           119           1             1  6.302521
# 63886   19       6           120           0             1  6.350000
# 63887   19       7           121           0             1  6.347107
#
#        last_five
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 63883       32.0
# 63884       32.0
# 63885       32.0
# 63886       33.0
# 63887       32.0
#
# [50501 rows x 17 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0             2     168           0    Australia    Sri Lanka   0.1       0
# 1             2     168           1    Australia    Sri Lanka   0.2       0
# 2             2     168           2    Australia    Sri Lanka   0.3       1
# 3             2     168           3    Australia    Sri Lanka   0.4       2
# 4             2     168           4    Australia    Sri Lanka   0.5       0
# ...         ...     ...         ...          ...          ...   ...     ...
# 50496       964     128         121    Sri Lanka    Australia  19.3       1
# 50497       964     128         122    Sri Lanka    Australia  19.4       0
# 50498       964     128         123    Sri Lanka    Australia  19.5       0
# 50499       964     128         124    Sri Lanka    Australia  19.6       2
# 50500       964     128         125    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 50496                 8    Colombo       R Premadasa Stadium            125
# 50497                 8    Colombo       R Premadasa Stadium            125
# 50498                 9    Colombo       R Premadasa Stadium            125
# 50499                 9    Colombo       R Premadasa Stadium            127
# 50500                 9    Colombo       R Premadasa Stadium            128
#
#       over ball_no  balls_bowled  balls_left  wickets_left       crr  \
# 0        0       1             1         119            10  0.000000
# 1        0       2             2         118            10  0.000000
# 2        0       3             3         117            10  2.000000
# 3        0       4             4         116            10  4.500000
# 4        0       5             5         115            10  3.600000
# ...    ...     ...           ...         ...           ...       ...
# 50496   19       3           117           3             2  6.410256
# 50497   19       4           118           2             2  6.355932
# 50498   19       5           119           1             1  6.302521
# 50499   19       6           120           0             1  6.350000
# 50500   19       7           121           0             1  6.347107
#
#        last_five
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 50496       32.0
# 50497       32.0
# 50498       32.0
# 50499       33.0
# 50500       32.0
#
# [50501 rows x 18 columns]

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)
# Out:
# <ipython-input-41-3665e38311c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 33284     Sri Lanka      England   Pallekele             82          52
# 46289     Sri Lanka  West Indies   Pallekele            188          12
# 34111  South Africa      England  Manchester             42          89
# 1080          India      England   Bangalore            136          29
# 13235     Australia        India      Sydney             79          63
# ...             ...          ...         ...            ...         ...
# 36741   West Indies   Bangladesh      Mirpur             69          68
# 48172         India   Bangladesh   Bangalore            104          32
# 46731  South Africa    Sri Lanka   Cape Town            154           4
# 45891      Pakistan  New Zealand    Auckland            105          34
# 40497         India    Australia      Mirpur             53          68
#
#        wickets_left        crr  last_five  runs_x
# 33284             7   7.235294       32.0     169
# 46289             7  10.444444       64.0     215
# 34111             7   8.129032       42.0      77
# 1080              7   8.967033       57.0     202
# 13235             9   8.315789       41.0     186
# ...             ...        ...        ...     ...
# 36741             8   7.961538       43.0     197
# 48172             7   7.090909       47.0     146
# 46731             5   7.965517       38.0     169
# 45891             7   7.325581       36.0     171
# 40497             7   6.115385       25.0     159
#
# [38477 rows x 9 columns]

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 24147     Australia      Pakistan      St Lucia             87          59
# 19058     Australia       England    Manchester            132           8
# 41484      Pakistan  South Africa     Cape Town             45          74
# 12794     Sri Lanka      Pakistan        Lahore            140           8
# 6751       Pakistan  South Africa     Centurion             61          76
# ...             ...           ...           ...            ...         ...
# 17825         India     Australia        Durban             40          75
# 46596  South Africa     Sri Lanka  Johannesburg            104          19
# 8047    New Zealand         India      Auckland            119          32
# 19053     Australia       England    Manchester            130          13
# 30723     Sri Lanka      Pakistan     Abu Dhabi            130          18
#
#        wickets_left       crr  last_five
# 24147             8  8.557377       38.0
# 19058             6  7.071429       49.0
# 41484             8  5.869565       32.0
# 12794             5  7.500000       45.0
# 6751              8  8.318182       37.0
# ...             ...       ...        ...
# 17825             9  5.333333       31.0
# 46596             3  6.178218       30.0
# 8047              6  8.113636       59.0
# 19053             7  7.289720       53.0
# 30723             6  7.647059       30.0
#
# [30781 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
# !pip install xgboost
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error
# Out:
# Collecting xgboost
#   Downloading xgboost-1.5.0-py3-none-win_amd64.whl (106.6 MB)
# Requirement already satisfied: numpy in c:\users\harsh\anaconda3\lib\site-packages (from xgboost) (1.19.2)
# Requirement already satisfied: scipy in c:\users\harsh\anaconda3\lib\site-packages (from xgboost) (1.5.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.0

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9861130581748087
# 1.7403503192933334

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']
